# %%
# !pip install --upgrade pip
# !pip install ultralytics
# Out:
# Requirement already satisfied: pip in d:\miniconda3\envs\ml\lib\site-packages (25.1)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------- ----------------- 1.0/1.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 5.9 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# D:\Miniconda3\envs\ml\python.exe -m pip install --upgrade pip
# Collecting ultralytics
#   Using cached ultralytics-8.3.146-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (3.10.3)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (6.0.2)
# Collecting requests>=2.23.0 (from ultralytics)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: scipy>=1.4.1 in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (2.7.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (0.22.0+cu118)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in d:\miniconda3\envs\ml\lib\site-packages (from ultralytics) (5.9.0)
# Collecting py-cpuinfo (from ultralytics)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\miniconda3\envs\ml\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\miniconda3\envs\ml\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\miniconda3\envs\ml\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\miniconda3\envs\ml\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\miniconda3\envs\ml\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\miniconda3\envs\ml\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\miniconda3\envs\ml\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->ultralytics)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\miniconda3\envs\ml\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock in d:\miniconda3\envs\ml\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\miniconda3\envs\ml\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\miniconda3\envs\ml\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in d:\miniconda3\envs\ml\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in d:\miniconda3\envs\ml\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in d:\miniconda3\envs\ml\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in d:\miniconda3\envs\ml\lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\miniconda3\envs\ml\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\miniconda3\envs\ml\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\miniconda3\envs\ml\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Using cached ultralytics-8.3.146-py3-none-any.whl (1.0 MB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.5 MB 7.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.5 MB 7.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.5 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.5 MB 8.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.5 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 8.4 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: pytz, py-cpuinfo, urllib3, tzdata, tqdm, opencv-python, idna, charset-normalizer, certifi, requests, pandas, ultralytics-thop, ultralytics
#
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    --------- ------------------------------  3/13 [tzdata]
#    ------------ ---------------------------  4/13 [tqdm]
#    ------------ ---------------------------  4/13 [tqdm]
#    ------------ ---------------------------  4/13 [tqdm]
#    --------------- ------------------------  5/13 [opencv-python]
#    --------------- ------------------------  5/13 [opencv-python]
#    --------------- ------------------------  5/13 [opencv-python]
#    ------------------ ---------------------  6/13 [idna]
#    --------------------- ------------------  7/13 [charset-normalizer]
#    --------------------- ------------------  7/13 [charset-normalizer]
#    --------------------------- ------------  9/13 [requests]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    --------------------------------- ------ 11/13 [ultralytics-thop]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ---------------------------------------- 13/13 [ultralytics]
#
# Successfully installed certifi-2025.4.26 charset-normalizer-3.4.2 idna-3.10 opencv-python-4.11.0.86 pandas-2.2.3 py-cpuinfo-9.0.0 pytz-2025.2 requests-2.32.3 tqdm-4.67.1 tzdata-2025.2 ultralytics-8.3.146 ultralytics-thop-2.0.14 urllib3-2.4.0

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n-seg.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-seg.pt to 'yolo11n-seg.pt'...
# 100%|██████████| 5.90M/5.90M [00:01<00:00, 4.69MB/s]

# %%
results = model("https://ultralytics.com/images/bus.jpg", save=True)

results[0].show
# Out:
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg'...
# 100%|██████████| 134k/134k [00:00<00:00, 1.08MB/s]
# image 1/1 d:\Fareed\IIIT Hyderabad Internship Projects\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 69.3ms
# Speed: 4.9ms preprocess, 69.3ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\segment\predict
# <bound method Results.show of ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: ultralytics.engine.results.Masks object
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[119, 146, 172],
#         [121, 148, 174],
#         [122, 152, 177],
#         ...,
#         [161, 171, 188],
#         [160, 170, 187],
#         [160, 170, 187]],
#
#        [[120, 147, 173],
#         [122, 149, 175],
#         [123, 153, 178],
#         ...,
#         [161, 171, 188],
#         [160, 170, 187],
#         [160, 170, 187]],
#
#        [[123, 150, 176],
#         [124, 151, 177],
#         [125, 155, 180],
#         ...,
#         [161, 171, 188],
#         [160, 170, 187],
#         [160, 170, 187]],
#
#        ...,
#
#        [[183, 182, 186],
#         [179, 178, 182],
#         [180, 179, 183],
#         ...,
#         [121, 111, 117],
#         [113, 103, 109],
#         [115, 105, 111]],
#
#        [[165, 164, 168],
#         [173, 172, 176],
#         [187, 186, 190],
#         ...,
#         [102,  92,  98],
#         [101,  91,  97],
#         [103,  93,  99]],
#
#        [[123, 122, 126],
#         [145, 144, 148],
#         [176, 175, 179],
#         ...,
#         [ 95,  85,  91],
#         [ 96,  86,  92],
#         [ 98,  88,  94]]], dtype=uint8)
# orig_shape: (1080, 810)
# path: 'd:\\Fareed\\IIIT Hyderabad Internship Projects\\bus.jpg'
# probs: None
# save_dir: 'runs\\segment\\predict'
# speed: {'preprocess': 4.923399999995581, 'inference': 69.32940000001508, 'postprocess': 8.658099999991009}>
